# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import optimizers
import matplotlib.pyplot as plt
import os

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
data_path = os.path.join("..", "data", "heart.csv")
data = np.loadtxt(data_path, delimiter=",", skiprows = 1)

# %%
x_data = np.array(data[:, 0:13], dtype = np.float32)
y_data = np.array(data[:, 13], dtype = np.float32)
y_data = y_data.reshape(1025, 1)

# %%
model = Sequential()
model.add(Input(shape = (13, )))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
opt = optimizers.Adam(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
history = model.fit(x_data, y_data, epochs = 500, batch_size = 50, verbose = 2)
# Out:
# Epoch 1/500
# 21/21 - 1s - loss: 4.6389 - accuracy: 0.5590 - 720ms/epoch - 34ms/step
# Epoch 2/500
# 21/21 - 0s - loss: 0.9119 - accuracy: 0.6420 - 144ms/epoch - 7ms/step
# Epoch 3/500
# 21/21 - 0s - loss: 0.5794 - accuracy: 0.7005 - 130ms/epoch - 6ms/step
# Epoch 4/500
# 21/21 - 0s - loss: 0.5434 - accuracy: 0.7171 - 102ms/epoch - 5ms/step
# Epoch 5/500
# 21/21 - 0s - loss: 0.5170 - accuracy: 0.7346 - 118ms/epoch - 6ms/step
# Epoch 6/500
# 21/21 - 0s - loss: 0.4711 - accuracy: 0.7571 - 71ms/epoch - 3ms/step
# Epoch 7/500
# 21/21 - 0s - loss: 0.4585 - accuracy: 0.7649 - 180ms/epoch - 9ms/step
# Epoch 8/500
# 21/21 - 0s - loss: 0.4942 - accuracy: 0.7590 - 73ms/epoch - 3ms/step
# Epoch 9/500
# 21/21 - 0s - loss: 0.4443 - accuracy: 0.7727 - 92ms/epoch - 4ms/step
# Epoch 10/500
# 21/21 - 0s - loss: 0.4106 - accuracy: 0.8283 - 76ms/epoch - 4ms/step
# Epoch 11/500
# 21/21 - 0s - loss: 0.4551 - accuracy: 0.7883 - 92ms/epoch - 4ms/step
# Epoch 12/500
# ...

# %%
accuracy = model.evaluate(x_data, y_data, verbose = 0)[1]
print('\n Accuracy: %.4f' % accuracy)
# Out:
#  Accuracy: 0.8800

# %%
plt.figure(figsize = (12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.tight_layout()
plt.show()
