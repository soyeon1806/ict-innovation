# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [[1, 0.2], [2, 0.3], [3, 0.5], [4, 0.6], [5, 0.9], [6, 0.95], [7, 1.1], [8, 1.5]]
x = [i[0] for i in data]
y = [i[1] for i in data]

# %%
plt.figure(figsize = (8, 5))
plt.scatter(x, y)
plt.show()

# %%
x_data = np.array(x)
y_data = np.array(y)

a = 0
b = 0

# %%
lr = 0.0001
epochs = 2001

# %%
for i in range(epochs):
    y_pred = a * x_data + b
    a_diff = 2/len(x_data) * sum((a * x_data + b - y_data) * x_data)
    b_diff = 2/len(x_data) * sum(a * x_data + b - y_data)

    a = a - lr * a_diff
    b = b - lr * b_diff

    if i% 100 == 0:
        print("epoch = %.f, 기울기 = %.04f, 절편 = %.04f" %(i, a, b))
# Out:
# epoch = 0, 기울기 = 0.0009, 절편 = 0.0002
# epoch = 100, 기울기 = 0.0679, 절편 = 0.0118
# epoch = 200, 기울기 = 0.1075, 절편 = 0.0186
# epoch = 300, 기울기 = 0.1309, 절편 = 0.0225
# epoch = 400, 기울기 = 0.1447, 절편 = 0.0247
# epoch = 500, 기울기 = 0.1529, 절편 = 0.0259
# epoch = 600, 기울기 = 0.1577, 절편 = 0.0265
# epoch = 700, 기울기 = 0.1606, 절편 = 0.0268
# epoch = 800, 기울기 = 0.1623, 절편 = 0.0268
# epoch = 900, 기울기 = 0.1633, 절편 = 0.0267
# epoch = 1000, 기울기 = 0.1640, 절편 = 0.0266
# epoch = 1100, 기울기 = 0.1643, 절편 = 0.0264
# epoch = 1200, 기울기 = 0.1646, 절편 = 0.0262
# epoch = 1300, 기울기 = 0.1648, 절편 = 0.0260
# epoch = 1400, 기울기 = 0.1649, 절편 = 0.0258
# epoch = 1500, 기울기 = 0.1650, 절편 = 0.0255
# epoch = 1600, 기울기 = 0.1650, 절편 = 0.0253
# epoch = 1700, 기울기 = 0.1651, 절편 = 0.0251
# epoch = 1800, 기울기 = 0.1651, 절편 = 0.0248
# epoch = 1900, 기울기 = 0.1652, 절편 = 0.0246
# epoch = 2000, 기울기 = 0.1652, 절편 = 0.0244

# %%
y_pred = a * x_data + b

# %%
plt.scatter(x, y)
plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
plt.show()
