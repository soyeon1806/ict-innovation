# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

# %%
plt.figure(figsize = (8, 5))
plt.scatter(x, y)
plt.show()

# %%
x_data = np.array(x)
y_data = np.array(y)

a = 0
b = 0

# %%
lr = 0.01
epochs = 2001

# %%
for i in range(epochs):
    y_pred = a * x_data + b
    a_diff = 2/len(x_data) * sum((a * x_data + b - y_data) * x_data)
    b_diff = 2/len(x_data) * sum(a * x_data + b - y_data)

    a = a - lr * a_diff
    b = b - lr * b_diff

    if i% 100 == 0:
        print("epoch = %.f, 기울기 = %.04f, 절편 = %.04f" %(i, a, b))
# Out:
# epoch = 0, 기울기 = 0.0928, 절편 = 0.0181
# epoch = 100, 기울기 = 6.9809, 절편 = 1.4269
# epoch = 200, 기울기 = 10.6722, 절편 = 2.2991
# epoch = 300, 기울기 = 12.6417, 절편 = 2.8820
# epoch = 400, 기울기 = 13.6837, 절편 = 3.3087
# epoch = 500, 기울기 = 14.2261, 절편 = 3.6508
# epoch = 600, 기울기 = 14.4996, 절편 = 3.9470
# epoch = 700, 기울기 = 14.6282, 절편 = 4.2182
# epoch = 800, 기울기 = 14.6788, 절편 = 4.4755
# epoch = 900, 기울기 = 14.6875, 절편 = 4.7249
# epoch = 1000, 기울기 = 14.6737, 절편 = 4.9698
# epoch = 1100, 기울기 = 14.6477, 절편 = 5.2119
# epoch = 1200, 기울기 = 14.6154, 절편 = 5.4520
# epoch = 1300, 기울기 = 14.5796, 절편 = 5.6908
# epoch = 1400, 기울기 = 14.5421, 절편 = 5.9285
# epoch = 1500, 기울기 = 14.5036, 절편 = 6.1653
# epoch = 1600, 기울기 = 14.4648, 절편 = 6.4012
# epoch = 1700, 기울기 = 14.4257, 절편 = 6.6363
# epoch = 1800, 기울기 = 14.3867, 절편 = 6.8706
# epoch = 1900, 기울기 = 14.3476, 절편 = 7.1042
# epoch = 2000, 기울기 = 14.3087, 절편 = 7.3370

# %%
y_pred = a * x_data + b

# %%
plt.scatter(x, y)
plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
plt.show()
