# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Dot, Activation, Concatenate
from tensorflow.keras.callbacks import EarlyStopping

# %%
chars = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
num_classes = len(chars)

char_to_index = {char: idx for idx, char in enumerate(chars)}
index_to_char = {idx: char for idx, char in enumerate(chars)}

# %%
# 데이터 생성 함수
def generate_data(num_samples):
    X = []
    y = []
    for _ in range(num_samples):
        sequence = np.random.choice(list(chars), 15)
        X.append([char_to_index[char] for char in sequence])
        y.append([char_to_index[char] for char in sequence[::-1]])
    return np.array(X), np.array(y)

# %%
# 데이터 생성
num_samples = 20000
X, y = generate_data(num_samples)

# %%
#인코더 정의
encoder_inputs = Input(shape = (15,))
encoder_embedding = Embedding(input_dim = num_classes, output_dim = 64, input_length = 15)(encoder_inputs)
encoder = LSTM(128, return_sequences = True, return_state = True)
encoder_outputs, state_h, state_c = encoder(encoder_embedding)
encoder_states = [state_h, state_c]

# %%
# 디코더 정의
decoder_inputs = Input(shape = (15, ))
decoder_embedding = Embedding(input_dim = num_classes, output_dim = 64, input_length = 15)(decoder_inputs)
decoder_lstm = LSTM(128, return_sequences = True, return_state = True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state = encoder_states)

# %%
# 어텐션 메커니즘
attention = Dot(axes = [2, 2])([decoder_outputs, encoder_outputs])
attention = Activation('softmax')(attention)
context = Dot(axes = [2, 1])([attention, encoder_outputs])

# %%
# 디코더 출력과 컨텐스트 결합
decoder_combined_context = Concatenate(axis = -1)([decoder_outputs, context])

# %%
# 출력 레이어
decoder_dense = Dense(num_classes, activation = 'softmax')
decoder_outputs = decoder_dense(decoder_combined_context)

# %%
# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
# 입력 데이터와 타겟 데이터를 동일하게 맞춤
decoder_input_data = np.zeros_like(X)

# %%
# EarlyStopping 콜백 정의
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights=True)

# %%
# 모델 학습
model.fit([X,decoder_input_data], y, epochs = 50, validation_split = 0.2, callbacks = [early_stopping])
# Out:
# Epoch 1/50
# 500/500 [==============================] - 11s 16ms/step - loss: 2.9161 - accuracy: 0.2621 - val_loss: 0.2181 - val_accuracy: 0.9975
# Epoch 2/50
# 500/500 [==============================] - 6s 13ms/step - loss: 0.0370 - accuracy: 0.9998 - val_loss: 0.0092 - val_accuracy: 0.9999
# Epoch 3/50
# 500/500 [==============================] - 6s 13ms/step - loss: 0.0723 - accuracy: 0.9903 - val_loss: 0.0054 - val_accuracy: 0.9999
# Epoch 4/50
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 5/50
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 6/50
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 0.9999
# Epoch 7/50
# 500/500 [==============================] - 10s 20ms/step - loss: 7.2511e-04 - accuracy: 1.0000 - val_loss: 7.9214e-04 - val_accuracy: 0.9999
# Epoch 8/50
# 500/500 [==============================] - 8s 17ms/step - loss: 4.9932e-04 - accuracy: 1.0000 - val_loss: 6.2666e-04 - val_accuracy: 0.9999
# Epoch 9/50
# 500/500 [==============================] - 10s 20ms/step - loss: 3.5489e-04 - accuracy: 1.0000 - val_loss: 4.9144e-04 - val_accuracy: 0.9999
# Epoch 10/50
# 500/500 [==============================] - 9s 18ms/step - loss: 2
-05 - val_accuracy: 1.0000
# Epoch 34/50
# 500/500 [==============================] - 9s 18ms/step - loss: 4.3695e-07 - accuracy: 1.0000 - val_loss: 4.4562e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 500/500 [==============================] - 8s 16ms/step - loss: 3.4177e-07 - accuracy: 1.0000 - val_loss: 3.7722e-05 - val_accuracy: 1.0000

# %%
# 모델 검증 함수
def predict_reverse(input_sequence):
    input_sequence = np.array([char_to_index[char] for char in input_sequence]).reshape(1, 15)
    decoder_input = np.zeros((1, 15))
    predicted_sequence = model.predict([input_sequence, decoder_input])
    predicted_indices = np.argmax(predicted_sequence, axis = -1).reshape((15, ))
    return ''.join([index_to_char[idx] for idx in predicted_indices])

# %%
# 검증용 문자열 리스트
test_strings = ["".join(np.random.choice(list(chars), 15)) for _ in range(30)]

# %%
# 실제 거꾸로 된 문자열 리스트
expected_outputs = [s[::-1] for s in test_strings]

# %%
# 모델 검증 및 정확도 계산
correct_predictoins = 0
total_predictions = len(test_strings)

for i, test_string in enumerate(test_strings):
    predicted_output = predict_reverse(test_string)
    is_correct = predicted_output == expected_outputs[i]

    if is_correct:
        correct_predictoins += 1
        print(f"입력: {test_string}")
        print(f"예측된 출력: {predicted_output}")
        print(f"실제 출력: {expected_outputs[i]}")
        print(f"정확 여부 {'맞음' if is_correct else '틀림'}\n")

accuracy = correct_predictoins / total_predictions
print(f"총 정확도: {accuracy * 100:.2f}%")
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 입력: dDaEuwjXZcjPxpM
# 예측된 출력: MpxPjcZXjwuEaDd
# 실제 출력: MpxPjcZXjwuEaDd
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 44ms/step
# 입력: OjatQODlZsEspQv
# 예측된 출력: vQpsEsZlDOQtajO
# 실제 출력: vQpsEsZlDOQtajO
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 41ms/step
# 입력: NGTECRrucEoWUAq
# 예측된 출력: qAUWoEcurRCETGN
# 실제 출력: qAUWoEcurRCETGN
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 45ms/step
# 입력: KjNjGVIjJKnpDfr
# 예측된 출력: rfDpnKJjIVGjNjK
# 실제 출력: rfDpnKJjIVGjNjK
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 46ms/step
# 입력: avZpMlIBblqBWtb
# 예측된 출력: btWBqlbBIlMpZva
# 실제 출력: btWBqlbBIlMpZva
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 42ms/step
# 입력: DkPZbWeswnOfyHp
# 예측된 출력: pHyfOnwseWbZPkD
# 실제 출력: pHyfOnwseWbZPkD
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 50ms/step
# 입력: hqxCtRjKCZARsEl
# 예측된 출력: lEsRAZCKjRtCxqh
# 실제 출력: lEsRAZCKjRtCxqh
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 43ms/step
# 입력: CqAMNlmNHDwIbCR
# 예측된 출력: RCbIwDHNmlNMAqC
# 실제 출력: RCbIwDHNmlNMAqC
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 46ms/step
# 입력: leEgyXvVIQZKnvy
# 예측된 출력: yvnKZQIVvXygEel
# 실제 출력: yvnKZQIVvXygEel
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 43ms/step
# 입력: avAfeFpZDKVeRMs
# 예측된 출력: sMReVKDZpFefAva
# 실제 출력: sMReVKDZpFefAva
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 43ms/step
# 입력: SOMYDcWGflUjrSF
# 예측된 출력: FSrjUlfGWcDYMOS
# 실제 출력: FSrjUlfGWcDYMOS
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 41ms/step
# 입력: OQniEkOkNhIncnD
# 예측된 출력: DncnIhNkOkEinQO
# 실제 출력: DncnIhNkOkEinQO
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 42ms/step
# 입력: yCwOVEHgVakNtll
# 예측된 출력: lltNkaVgHEVOwCy
# 실제 출력: lltNkaVgHEVOwCy
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 54ms/step
# 입력: fqewyNDeDhawtSl
# 예측된 출력: lStwahDeDNyweqf
# 실제 출력: lStwahDeDNyweqf
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 45ms/step
# 입력: jsdvOmUXAAymTyV
# 예측된 출력: VyTmyAAXUmOvdsj
# 실제 출력: VyTmyAAXUmOvdsj
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 40ms/step
# 입력: jjtWncKIuQMuObF
# 예측된 출력: FbOuMQuIKcnWtjj
# 실제 출력: FbOuMQuIKcnWtjj
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 44ms/step
# 입력: gxTyZbhWoZIaTFY
# 예측된 출력: YFTaIZoWhbZyTxg
# 실제 출력: YFTaIZoWhbZyTxg
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 50ms/step
# 입력: eFYXFrqWsWtSZAu
# 예측된 출력: uAZStWsWqrFXYFe
# 실제 출력: uAZStWsWqrFXYFe
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 39ms/step
# 입력: fgbqDtdvDYKZnEH
# 예측된 출력: HEnZKYDvdtDqbgf
# 실제 출력: HEnZKYDvdtDqbgf
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 38ms/step
# 입력: sXYVsgzpLHVXMsn
# 예측된 출력: nsMXVHLpzgsVYXs
# 실제 출력: nsMXVHLpzgsVYXs
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 49ms/step
# 입력: wKMSMqyUNrkblTU
# 예측된 출력: UTlbkrNUyqMSMKw
# 실제 출력: UTlbkrNUyqMSMKw
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 49ms/step
# 입력: tomYelvsgMJlacy
# 예측된 출력: ycalJMgsvleYmot
# 실제 출력: ycalJMgsvleYmot
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 43ms/step
# 입력: kLNUJVOhjaMolKU
# 예측된 출력: UKloMajhOVJUNLk
# 실제 출력: UKloMajhOVJUNLk
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 41ms/step
# 입력: PpzvjRPXIXpBGzx
# 예측된 출력: xzGBpXIXPRjvzpP
# 실제 출력: xzGBpXIXPRjvzpP
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 42ms/step
# 입력: mogZbgLUvTpGBSx
# 예측된 출력: xSBGpTvULgbZgom
# 실제 출력: xSBGpTvULgbZgom
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 46ms/step
# 입력: CwnusJHAYuXxFKU
# 예측된 출력: UKFxXuYAHJsunwC
# 실제 출력: UKFxXuYAHJsunwC
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 54ms/step
# 입력: PGxiUumFqwnkpsJ
# 예측된 출력: JspknwqFmuUixGP
# 실제 출력: JspknwqFmuUixGP
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 50ms/step
# 입력: WGaFokpPbWynAGV
# 예측된 출력: VGAnyWbPpkoFaGW
# 실제 출력: VGAnyWbPpkoFaGW
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 48ms/step
# 입력: pUSJABzkzPmyvFW
# 예측된 출력: WFvymPzkzBAJSUp
# 실제 출력: WFvymPzkzBAJSUp
# 정확 여부 맞음
#
# 1/1 [==============================] - 0s 44ms/step
# 입력: oOoWnybaOhHSMFo
# 예측된 출력: oFMSHhOabynWoOo
# 실제 출력: oFMSHhOabynWoOo
# 정확 여부 맞음
#
# 총 정확도: 100.00%
